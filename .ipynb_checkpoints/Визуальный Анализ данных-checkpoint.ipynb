# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
#Загрука данных 
Data = pd.read_csv("Parsing_Cian.csv", sep = ',')

# %% [markdown]
# ### Взглянем на Фрейм

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8393 entries, 0 to 8392
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                7592 non-null   object
#  1   author_type           7595 non-null   object
#  2   url                   7906 non-null   object
#  3   location              7906 non-null   object
#  4   deal_type             7906 non-null   object
#  5   accommodation_type    7906 non-null   object
#  6   floor                 7906 non-null   object
#  7   floors_count          7906 non-null   object
#  8   rooms_count           7906 non-null   object
#  9   total_meters          7906 non-null   object
#  10  price                 7893 non-null   object
#  11  year_of_construction  7906 non-null   object
#  12  object_type           7906 non-null   object
#  13  have_loggia           7906 non-null   object
#  14  parking_type          7906 non-null   object
#  15  house_material_type   7906 non-null   object
#  16  heating_type          7906 non-null   object
#  17  finish_type           7906 non-null   object
#  18  living_meters         7906 non-null   object
#  19  kitchen_meters        7906 non-null   object
#  20  phone                 7906 non-null   object
#  21  ceiling_height        7906 non-null   object
#  22  district              3127 non-null   object
#  23  street                6255 non-null   object
#  24  house_number          6699 non-null   object
#  25  underground           5511 non-null   object
#  26  residential_complex   3971 non-null   object
# dtypes: object(27)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Избавимся от дубиликатов

# %%
Data.drop_duplicates()
# Out:
#                                  author        author_type  \
# 0                          ID 115709096          homeowner
# 1     Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                            ID 3246838            realtor
# 3                           ID 64398571            unknown
# 4                             ЛИДЕРМЭЙН  real_estate_agent
# ...                                 ...                ...
# 8388                              МИЭЛЬ  real_estate_agent
# 8389                                ПИК          developer
# 8390                        ID 47276638          homeowner
# 8391                         EstateLiga  real_estate_agent
# 8392                                ПИК          developer
#
#                                                  url  location deal_type  \
# 0     https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1     https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2     https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3     https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4     https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# ...                                              ...       ...       ...
# 8388  https://mytishchi.cian.ru/sale/flat/308939371/    Мытищи      sale
# 8389  https://mytishchi.cian.ru/sale/flat/306943495/    Мытищи      sale
# 8390  https://mytishchi.cian.ru/sale/flat/294184046/    Мытищи      sale
# 8391  https://mytishchi.cian.ru/sale/flat/304572510/    Мытищи      sale
# 8392  https://mytishchi.cian.ru/sale/flat/303513303/    Мытищи      sale
#
#      accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0                  flat     6            6           1         20.7  ...
# 1                  flat     1            9           1         33.0  ...
# 2                  flat     4            4           1         14.0  ...
# 3                  flat     5            5           1         17.5  ...
# 4                  flat     4            7           1         25.9  ...
# ...                 ...   ...          ...         ...          ...  ...
# 8388               flat     8           14           2         69.7  ...
# 8389               flat    19           25           2         48.1  ...
# 8390               flat     3            5           2         45.0  ...
# 8391               flat     3            6           2         34.0  ...
# 8392               flat     3           16           2         58.6  ...
#
#      finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0             -1         18 м²           1 м²  79175096253            3 м
# 1             -1         18 м²           6 м²  79645530086          2,7 м
# 2             -1            -1             -1  79807126116             -1
# 3             -1            -1             -1  79645652380             -1
# 4             -1         20 м²           5 м²  79099408093          3,5 м
# ...          ...           ...            ...          ...            ...
# 8388          -1         38 м²        10,5 м²  79672094035             -1
# 8389    Чистовая       22,7 м²        16,1 м²  74951370494         2,62 м
# 8390          -1            -1           6 м²  79153266030             -1
# 8391          -1         19 м²           8 м²  79651097781         2,75 м
# 8392    Чистовая       24,9 м²        21,4 м²  74951348120         2,62 м
#
#                      district                street house_number underground  \
# 0                    Серпухов               Крюкова            4         NaN
# 1                         NaN            Ворошилова          144      Аннино
# 2     Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                    Серпухов           Российская            40         NaN
# 4                    Серпухов               Химиков            8         NaN
# ...                       ...                   ...          ...         ...
# 8388                      NaN            Юбилейная             6  Медведково
# 8389                      NaN                   NaN          NaN   Ростокино
# 8390                      NaN            Юбилейная          11к3  Медведково
# 8391                      NaN      бульвар Тенистый            5  Медведково
# 8392                      NaN                   NaN          NaN  Медведково
#
#          residential_complex
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 8388             Ярославский
# 8389  Ярославский квартал ЖК
# 8390                     NaN
# 8391    Императорские Мытищи
# 8392            Яуза Парк ЖК
#
# [7577 rows x 27 columns]

# %% [markdown]
# ## Обозначение Колонок

# %% [markdown]
# * url - ссылка
# * location           - локация объявления (город)
# * deal_type          - тип объявления (продажа/аренда)
# * accommodation_type - тип жилья (квартира, дом и т.д.)
# * floor	           - этаж квартиры
# * floors_count	   - количество этажей
# * total_meters	   - площадь квартиры
# * price	           - общая стоимость
# * seller- 	является ли продавец агентом
# * year_of_construction	год постройки здания
# * object_type	тип жилья (новостройка\вторичка)
# * have_loggia	наличие лоджий\балконов
# * house_material_type	тип дома (монолитный, панельный и т.д.)
# * heating_type	тип отопления
# * finish_type	отделка
# * living_meters	жилая площадь
# * kitchen_meters	площадь кухни
# * phone	номер телефона
# * ceiling_height	высота потолка
# * district	район
# * street	улица
# * house_number	номер дома
# * underground	метро (+ мцд)
# * residential_complex	жилой комплекс

# %%
# Выыедим первые 8 строк 
Data.head(8)
# Out:
#                               author        author_type  \
# 0                       ID 115709096          homeowner
# 1  Самолёт плюс Подмосковье Серпухов  real_estate_agent
# 2                         ID 3246838            realtor
# 3                        ID 64398571            unknown
# 4                          ЛИДЕРМЭЙН  real_estate_agent
# 5                        Максим Юсов  real_estate_agent
# 6                         ID 9655060            unknown
# 7                     Этажи Серпухов  real_estate_agent
#
#                                               url  location deal_type  \
# 0  https://serpukhov.cian.ru/sale/flat/301136001/  Серпухов      sale
# 1  https://serpukhov.cian.ru/sale/flat/305145433/  Серпухов      sale
# 2  https://serpukhov.cian.ru/sale/flat/308145954/  Серпухов      sale
# 3  https://serpukhov.cian.ru/sale/flat/309086009/  Серпухов      sale
# 4  https://serpukhov.cian.ru/sale/flat/308401669/  Серпухов      sale
# 5  https://serpukhov.cian.ru/sale/flat/304233768/  Серпухов      sale
# 6  https://serpukhov.cian.ru/sale/flat/304697154/  Серпухов      sale
# 7  https://serpukhov.cian.ru/sale/flat/304332318/  Серпухов      sale
#
#   accommodation_type floor floors_count rooms_count total_meters  ...  \
# 0               flat     6            6           1         20.7  ...
# 1               flat     1            9           1         33.0  ...
# 2               flat     4            4           1         14.0  ...
# 3               flat     5            5           1         17.5  ...
# 4               flat     4            7           1         25.9  ...
# 5               flat     2            3           1         46.7  ...
# 6               flat     3            5           1         29.0  ...
# 7               flat     3            6           1         19.1  ...
#
#   finish_type living_meters kitchen_meters        phone ceiling_height  \
# 0          -1         18 м²           1 м²  79175096253            3 м
# 1          -1         18 м²           6 м²  79645530086          2,7 м
# 2          -1            -1             -1  79807126116             -1
# 3          -1            -1             -1  79645652380             -1
# 4          -1         20 м²           5 м²  79099408093          3,5 м
# 5          -1         25 м²           6 м²  79647820594             -1
# 6          -1         25 м²             -1  79645658245            3 м
# 7          -1            -1             -1  79647821411             -1
#
#                   district                street house_number underground  \
# 0                 Серпухов               Крюкова            4         NaN
# 1                      NaN            Ворошилова          144      Аннино
# 2  Красный Текстильщик мкр   Красный Текстильщик            2         NaN
# 3                 Серпухов           Российская            40         NaN
# 4                 Серпухов               Химиков            8         NaN
# 5                 Серпухов        2-я Московская          6к3         NaN
# 6                 Серпухов                Форсса           10         NaN
# 7                 Серпухов               Крюкова            4         NaN
#
#   residential_complex
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
#
# [8 rows x 27 columns]

# %%
show = Data.shape
print(f"В Датафрейме Колонок:{show[1]}  Строк:{show[0]}")
# Out:
# В Датафрейме Колонок:27  Строк:8393

# %% [markdown]
# ### Проанализиурем и определим колонки кторые влияют или могут влиять на цену квартиры

# %% [markdown]
# Согласно статьи из сайта по поиску, продаже и подборe квартиры ЦИАН
# https://www.cian.ru/blogs-kakie-faktory-vlijajut-na-rynochnuju-stoimost-kvartiry-273638/
# на цену могут влиять следующие факторы :

# %% [markdown]
# * Метраж Кухни
# * Наличие парковки и её тип
# * Этаж расположения квартиры
# * Общее количество этажей
# * Отделка
# * Новостройка/Вторичка
# * Год Постройки
# * Удалённость от Метро
# * Наличие Балкона

# %% [markdown]
# Исходя из времени работы компании на рынке недвижемости и отзовы о работе платформы, можно опираться на их даннын при анализе колонок .

# %% [markdown]
# Определим колонки которые могут влиять на цену квартиры

# %% [markdown]
# Колонки :

# %% [markdown]
# * residential_complex - название жилого комплекса ,
# * district            - район,
# * phone               - Телефон,
# * street              - Улица
# * url                 - ссылка.
# * deal_type           - Тип сделки
# * accommodation_type  - Тип Размещения
# * house_number        - Номер Дома
# * heating_type        - Отопление
#
# никак не влияют на цену квартиры, удаляем их

# %%
#Удаляем ненужные колонки
Data_Purified = Data.drop(["residential_complex", "district", "phone", "street", "url", "deal_type", "accommodation_type" , "location", "house_number", "author", "author_type", "heating_type"] , axis = 1)

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8393 entries, 0 to 8392
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 7906 non-null   object
#  1   floors_count          7906 non-null   object
#  2   rooms_count           7906 non-null   object
#  3   total_meters          7906 non-null   object
#  4   price                 7893 non-null   object
#  5   year_of_construction  7906 non-null   object
#  6   object_type           7906 non-null   object
#  7   have_loggia           7906 non-null   object
#  8   parking_type          7906 non-null   object
#  9   house_material_type   7906 non-null   object
#  10  finish_type           7906 non-null   object
#  11  living_meters         7906 non-null   object
#  12  kitchen_meters        7906 non-null   object
#  13  ceiling_height        7906 non-null   object
#  14  underground           5511 non-null   object
# dtypes: object(15)
# memory usage: 983.7+ KB

# %% [markdown]
# ## Первичная Обработка Данных

# %% [markdown]
# Согласно описанию библиотеки по сбору данных отсутсвующие значения заменялись на '-1' Заменим их на NaN

# %%
Data_Purified.replace("-1", np.nan, inplace = True)

# %% [markdown]
# Посмотрим количество нулевых значений и пропусков

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='cividis')
# Out:
# <Axes: >

# %%
null_ = Data_Purified.isnull().sum().reset_index()
null_.columns = ['Колонки', 'NaN']
print(null_)
# Out:
#                  Колонки   NaN
# 0                  floor   487
# 1           floors_count   487
# 2            rooms_count   587
# 3           total_meters   487
# 4                  price   500
# 5   year_of_construction  1856
# 6            object_type   487
# 7            have_loggia  3895
# 8           parking_type  3981
# 9    house_material_type  6946
# 10           finish_type  6387
# 11         living_meters  2269
# 12        kitchen_meters  1838
# 13        ceiling_height  3258
# 14           underground  2882

# %% [markdown]
# ### В колонках house_material_type и finish_type много пропусков удаляем колонки

# %%
Data_Purified.drop(["house_material_type", "finish_type"], axis = 1 , inplace = True )

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8393 entries, 0 to 8392
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 7906 non-null   object
#  1   floors_count          7906 non-null   object
#  2   rooms_count           7806 non-null   object
#  3   total_meters          7906 non-null   object
#  4   price                 7893 non-null   object
#  5   year_of_construction  6537 non-null   object
#  6   object_type           7906 non-null   object
#  7   have_loggia           4498 non-null   object
#  8   parking_type          4412 non-null   object
#  9   living_meters         6124 non-null   object
#  10  kitchen_meters        6555 non-null   object
#  11  ceiling_height        5135 non-null   object
#  12  underground           5511 non-null   object
# dtypes: object(13)
# memory usage: 852.5+ KB

# %% [markdown]
# ## Обработка Данных

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8393 entries, 0 to 8392
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 7906 non-null   object
#  1   floors_count          7906 non-null   object
#  2   rooms_count           7806 non-null   object
#  3   total_meters          7906 non-null   object
#  4   price                 7893 non-null   object
#  5   year_of_construction  6537 non-null   object
#  6   object_type           7906 non-null   object
#  7   have_loggia           4498 non-null   object
#  8   parking_type          4412 non-null   object
#  9   living_meters         6124 non-null   object
#  10  kitchen_meters        6555 non-null   object
#  11  ceiling_height        5135 non-null   object
#  12  underground           5511 non-null   object
# dtypes: object(13)
# memory usage: 852.5+ KB

# %% [markdown]
# Посмотрим колонки которые должны иметь числовые значения На Предмет анамалий

# %% [markdown]
# * floor-
# * floors_count
# * rooms_count
# * total_meters
# * price
# * kitchen_meters
# * ceiling_height
# * living_meters
# * year_of_construction

# %%
for i in Data_Purified.columns:
    print(f"{i} : {Data_Purified[i].unique()}", end ="\n")
# Out:
# floor : ['6' '1' '4' '5' '2' '3' '15' '8' '7' '9' '18' '13' '10' '11' '35' '22'
#  '12' '20' '14' '19' '37' '24' '28' '17' '34' '16' '40' '21' '41' '30'
#  '33' '29' '23' '25' '26' '75' '62' '31' '46' '48' '80' '53' '38' '27'
#  '57' '59' '32' '36' '47' '82' nan '39' '79' 'floor' '66' '60' '51']
# floors_count : ['6' '9' '4' '5' '7' '3' '2' '17' '10' '24' '1' '14' '18' '12' '23' '20'
#  '41' '21' '43' '8' '59' '40' '27' '15' '13' '16' '22' '29' '25' '30' '49'
#  '31' '39' '53' '28' '85' '35' '26' '32' '34' '57' '19' '11' '36' '68'
#  '38' '51' '78' '79' '47' '33' '64' '75' '45' '37' '63' '95' '52' '54'
#  '77' '46' '44' '67' '50' '48' '76' '42' '55' '56' nan '97' '65'
#  'floors_count' '66']
# rooms_count : ['1' '2' nan '3' '4' '5' 'rooms_count']
# total_meters : ['20.7' '33.0' '14.0' ... '30.47' '36.79' '48.39']
# price : ['2350000' '4150000' '1700000' ... '9865233' '8607014' '13014356']
# year_of_construction : ['1917' '1975' nan '1968' '2009' '1969' '1980' '1990' '1964' '2025' '2015'
#  '1970' '1984' '1965' '2010' 'Аукцион' '1992' '2011' '1986' '1994' '1956'
#  '1966' '1973' '1971' '1957' '2013' '1981' '1972' '1959' '2004' '1962'
#  '2019' '1978' '1977' '2003' '1963' '1952' '2024' '2007' '1995' '1976'
#  '1982' '1953' '2008' '2026' '2023' '1941' '2028' '1993' '2016' '2027'
#  '2017' '2022' '1932' '2012' '1960' '2006' '1926' '2020' '1943' '2014'
#  '2021' '1967' '1904' '1991' '2018' '1987' '1988' '1974' 'Напишите автору'
#  '1979' '1929' '1989' '1985' '1930' '2005' '1958' '1996' '1940' '1948'
#  '1961' '1938' '1997' '2002' '2001' '1999' '1983' '1998' '1902' '2000'
#  '1915' '1910' '1939' '1954' '1897' '1955' '1900' 'Позвоните автору'
#  '1949' '1947' '1901' '1909' '1600' '1951' '1936' 'year_of_construction'
#  '1931' '1950' '1934' '1928' '1945' '1937' '1927' '1896' '1777' '2031'
#  '1935']
# object_type : ['Вторичка' 'Новостройка' 'Вторичка / Апартаменты'
#  'Новостройка / Апартаменты' 'Вторичка / Пентхаус'
#  'Новостройка / Пентхаус' nan 'object_type']
# have_loggia : [nan '1 лоджия' '1 балкон' '3 лоджии' '2 лоджии' '1 лоджия, 1 балкон'
#  '2 балкона' '3 балкона' '4 балкона' '1 лоджия, 2 балкона'
#  '2 лоджии, 1 балкон' '2 лоджии, 2 балкона' '4 лоджии' 'have_loggia']
# parking_type : ['Наземная' nan 'Многоуровневая' 'Подземная' 'Открытая' 'parking_type']
# living_meters : ['18\xa0м²' nan '20\xa0м²' '25\xa0м²' '29,7\xa0м²' '24,9\xa0м²'
#  '4,4\xa0м' '2,58\xa0м' '52\xa0м' '2,26\xa0м' '2,3\xa0м' '1,65\xa0м'
#  '3,17\xa0м' '2,98\xa0м' '3,72\xa0м' '2,97\xa0м' '3,01\xa0м' '2,71\xa0м'
#  '0\xa0м' '2,7800000000000002\xa0м' 'ceiling_height' '3,36\xa0м'
#  '3,7\xa0м' '25\xa0м' '9\xa0м' '3,34\xa0м' '5,5\xa0м' '5,1\xa0м'
#  '4,55\xa0м' '2,61\xa0м' '2,81\xa0м' '2,2\xa0м']
# underground : [nan 'Аннино' 'Силикатная' 'Поклонная' 'Белорусская' 'Бауманская'
#  'Тульская' 'Фили' 'Аэропорт' 'Улица 1905 года' 'Смоленская' 'Дмитровская'
#  'Давыдково' 'Маяковская' 'ЦСКА' 'Улица Академика Янгеля'
#  'Лермонтовский проспект' 'Зеленоград — Крюково' 'Говорово'
#  'Цветной бульвар' 'Ясенево' 'Преображенская площадь' 'Юго-Западная'
#  'Новые Черёмушки' 'Гражданская' 'Октябрьское поле' 'ЗИЛ' 'Орехово'
#  'Рассказовка' 'Арбатская' 'Аминьевская' 'Полянка' 'Кунцевская'
#  'Марьина Роща' 'Трубная' 'Речной вокзал' 'Павелецкая'
#  'Ломоносовский проспект' 'Молодёжная' 'Щукинская' 'Авиамоторная'
#  'Москва-Сити' 'Новокузнецкая' 'Алексеевская' 'Пушкинская' 'Сокольники'
#  'Нагатинская' 'Шелепиха' 'Сухаревская' 'Парк Победы' 'Крёкшино'
#  'Солнцево' 'Бунинская аллея' 'Кедровая' 'Филатов Луг' 'Щербинка'
#  'Новомосковская' 'Воронцовская' 'Парк Культуры' 'Фрунзенская'
#  'Сходненская' 'Соколиная гора' 'Ленинский проспект' 'Матвеевская'
#  'Потапово' 'Мичуринец' 'Красный Балтиец' 'Стахановская' 'Тёплый Стан'
#  'Хорошёвская' 'Краснопресненская' 'Спортивная' 'Савёловская'
#  'Кутузовская' 'Полежаевская' 'Серпуховская' 'Спартак' 'Сокол' 'Свиблово'
#  'Юго-Восточная' 'Народное Ополчение' 'Братиславская' 'Коптево'
#  'Ватутинки' 'Стрешнево' 'Марьино' 'Щёлковская' 'Пражская' 'Нижегородская'
#  'Площадь Гагарина' 'Летово' 'Апрелевка' 'Корниловская' 'Толстопальцево'
#  'Окружная' 'Румянцево' 'Новопеределкино' 'Пятницкое шоссе' 'Кузьминки'
#  'Прокшино' 'Некрасовка' 'Медведково' 'Новокосино' 'Каширская' 'Отрадное'
#  'Крымская' 'Достоевская' 'Никольское' 'Реутов' 'Одинцово' 'Люберцы'
#  'Панки' 'Лухмановская' 'Академическая' 'Приморская' 'Курская'
#  'Чкаловская' 'Верхние Лихоборы' 'Ховрино' 'Проспект Ветеранов'
#  'Шаболовская' 'Динамо' 'Технопарк' 'Рабочий посёлок' 'Площадь Маркса'
#  'Комендантский проспект' 'Китай-город' 'Новослободская' 'Дубровка'
#  'Лесная' 'ВДНХ' 'Серебряный Бор' 'Славянский бульвар' 'Деловой центр'
#  'Дубравная' 'Москва-Товарная' 'Ломоносовская' 'Алма-Атинская'
#  'Железнодорожная' 'Фонвизинская' 'Крестовский остров' 'Хлебниково'
#  'Долгопрудная' 'Водники' 'Селигерская' 'Коломенская' 'Боровицкая'
#  'Верхние котлы' 'Ольховая' 'Филёвский парк' 'Кантемировская'
#  'Площадь Революции' 'Раменки' 'Киевская' 'Тушинская' 'Кропоткинская'
#  'Саларьево' 'Водный стадион' 'Лобня' 'Планерная' 'Сходня' 'Подрезково'
#  'Молжаниново' 'Шереметьевская' 'Химки' 'Новоподрезково' 'Левобережная'
#  'Перово' 'Угрешская' 'Электрозаводская' 'Кузнецкий мост' 'Южная'
#  'Кавказский бульвар' 'Первомайская' 'Профсоюзная' 'Воробьёвы горы'
#  'Минская' 'Люблино' 'Мнёвники' 'Мичуринский проспект' 'Ботанический сад'
#  'Москворечье' 'Домодедовская' 'Зюзино' 'Тропарёво' 'Красносельская'
#  'Озёрная' 'Бульвар Генерала Карбышева' 'Беломорская' 'Нагорная' 'Пыхтино'
#  'Тургеневская' 'Варшавская' 'Владыкино' 'Ростокино' 'Комсомольская'
#  'Алтуфьево' 'Физтех' 'Кокошкино' 'Новогиреево' 'Тверская' 'Беговая'
#  'Менделеевская' 'Семёновская' 'Автозаводская' 'Крестьянская застава'
#  'Волоколамская' 'Трикотажная' 'Новаторская' 'Площадь Ильича' 'Калитники'
#  'Салтыковская' 'Кучино' 'Ольгино' 'Остафьево' 'Подольск' 'Раменское'
#  'Есенинская' 'Фабричная' 'Ипподром' 'Павшино' 'Бутово' 'Красногорская'
#  'Новодачная' 'Площадь 1905 года' 'Пионерская' 'Козья слобода'
#  'Бабушкинская' 'Горки' 'Серп и Молот' 'Терехово ' 'Кремлёвская'
#  'Рыбацкое' 'Авиастроительная' 'Северный Вокзал' 'Ладожская' 'Яшьлек'
#  'Проспект Победы' 'Новочеркасская' 'Проспект Большевиков' 'Парнас'
#  'Выборгская' 'Черная речка' 'Студенческая' 'Площадь Ленина'
#  'Улица Дыбенко' 'Московские ворота' 'Гагаринская' 'Кировский завод'
#  'Горьковская' 'Площадь Тукая' 'Горный институт' 'Сколково' 'Липовая Роща'
#  'Лубянка' 'Безымянка' 'Девяткино' 'Технологический институт' 'Ильинская'
#  'Елизаровская' 'Балтийская' 'Звездная' 'Алабинская' 'Купчино' 'Аметьево'
#  'Строгино' 'Победа' 'Курьяново' 'Зорге' 'Черкизовская' 'Третьяковская'
#  'Пролетарская' 'Улица Милашенкова' 'Красные ворота' 'Перерва'
#  'Кожуховская' 'Хорошёво' 'Октябрьская' 'Театральная' 'Панфиловская'
#  'Бутырская' 'Университет' 'Машиностроителей' 'Удельная' 'Опалиха'
#  'Царицыно' 'Василеостровская' 'Бульвар Рокоссовского' 'Площадь Мужества'
#  'Бачуринская' 'Гражданский проспект' 'Заельцовская' 'Ботаническая'
#  'Котельники' 'underground' 'Выхино' 'Грачёвская' 'Гольяново'
#  'Улица Сергея Эйзенштейна' 'Партизанская' 'Битца' 'Бирюлёво' 'Коньково'
#  'Крылатское' 'Нахабино' 'Ухтомская' 'Жулебино' 'Проспект Просвещения'
#  'Митино' 'Обводный канал' 'Площадь Восстания' 'Чернышевская'
#  'Гостиный двор' 'Севастопольская' 'Автово' 'Геологическая' 'Юнгородок'
#  'Отдых' 'Внуково' 'Волгоградский проспект' 'Нарвская' 'Волковская'
#  'Шушары' 'Фирсановская' 'Марк' 'Пенягино' 'Аникеевка' 'Мякинино'
#  'Белокаменная']

# %% [markdown]
# ### Столбец имеет значемние анамалиюю floor обработаем и удалим его

# %%
index = Data_Purified[Data_Purified["floor"] == "floor"].index

# %%
Data_Purified.drop(index , inplace=True )

# %%
Data_Purified["floors_count"].unique()
# Out:
# array(['6', '9', '4', '5', '7', '3', '2', '17', '10', '24', '1', '14',
#        '18', '12', '23', '20', '41', '21', '43', '8', '59', '40', '27',
#        '15', '13', '16', '22', '29', '25', '30', '49', '31', '39', '53',
#        '28', '85', '35', '26', '32', '34', '57', '19', '11', '36', '68',
#        '38', '51', '78', '79', '47', '33', '64', '75', '45', '37', '63',
#        '95', '52', '54', '77', '46', '44', '67', '50', '48', '76', '42',
#        '55', '56', nan, '97', '65', '66'], dtype=object)

# %% [markdown]
# ## Обработаем kitchen_meters

# %%
Data_Purified["kitchen_meters"] = Data_Purified["kitchen_meters"].str.replace('\xa0м²', '', regex=True).str.replace(',', '.')

# %%
Data_Purified["kitchen_meters"].unique()
# Out:
# array(['1', '6', nan, '5', '5.6', '16', '3', '6.2', '7', '7.3', '6.1',
#        '10', '9', '8', '5.7', '11', '7.5', '13.5', '6.5', '5.8', '20',
#        '11.2', '7.8', '4', '7.9', '4.1', '12', '7.7', '8.1', '9.3',
#        '10.2', '10.6', '8.5', '9.1', '4.5', '6.7', '45', '34.3', '25.5',
#        '46.2', '4.9', '8.4', '24.9', '15', '15.8', '11.5', '5.5', '10.7',
#        '19.4', '43.8', '44.5', '22.4', '25', '28.4', '19', '21', '5.1',
#        '18.3', '3.8', '19.2', '16.2', '21.7', '12.5', '15.4', '28', '17',
#        '10.4', '13.6', '21.8', '14', '12.9', '13', '29.2', '23', '15.7',
#        '2.9', '8.2', '2.4', '20.7', '4.3', '18', '21.3', '11.6', '16.8',
#        '3.9', '9.9', '19.3', '11.3', '14.8', '17.1', '21.4', '8.9',
#        '18.2', '13.4', '16.4', '16.5', '8.7', '9.8', '10.8', '18.5',
#        '16.1', '13.2', '8.6', '4.8', '9.5', '6.3', '3.5', '43', '65',
#        '9.2', '12.7', '10.1', '7.1', '12.8', '10.5', '25.6', '6.4', '7.2',
#        '9.7', '15.2', '7.6', '9.6', '3.2', '7.4', '5.2', '6.6', '2',
#        '2.5', '3.6', '5.4', '3.3', '4.4', '16.6', '24', '15.6', '19.9',
#        '28.7', '15.3', '22', '16.7', '11.9', '12.4', '23.9', '14.3',
#        '8.8', '4.2', '22.3', '15.5', '21.5', '25.1', '10.3', '22.1', '30',
#        '11.5', '49.9', '34.2', '31.3', '29.3', '39.2', '26.3', '20.2',
#        '26.5', '43', '29.4', '23.3', '32.4', '35.3', '16.3', '53.4', '71',
#        '22.5', '50.3', '33.3', '30.2', '26.6', '37.2', '36.2', '36.4',
#        '30.9', '42.5', '23.2', '28.7', '37.6', '27.1', '35.6', '58.2',
#        '33.2', '25.6', '31.8', '24.6', '48.3', '58', '96.9', '25.1',
#        '27.3', '23.1', '21.9', '13.6', '24.5', '31.1', '51.5', '22.4',
#        '15.4', '39.6', '47', '49.5', '44.5', '29.8', '41.2', '33.4',
#        '32.3', '26.2', '21.1', '21.4', '30.6', '41.3', '26.9', '24.7',
#        '30.8', '26.1', '39.5', '35.8', '40.7', '38.4', '46.1', '34.7',
#        '43.6', '23.6', '38.9', '38.1', '47.8', '45.3', '67.2', '48.5',
#        '62.2', '43.5', '57.2', '65', '49.1', '58.3', '42.1', '55.9',
#        '54.2', '38.6', '51', '52.3', '48.2', '42.4', '48.7', '56.1',
#        '45.5', '63', '64', '39.8', '62.5', '43.2', '35.5', '54.3', '49.4',
#        '53.5', '41.8', '47.1', '55.1', '40.2', '59', '56.2', '43.4', '68',
#        '43.9', '52.8', '45.4', '45.6', '49.2', '44.7', '37.5', '41.1',
#        '46.3', '45.7', '67.4', '49.8', '43.3', '47.7', '48.6', '50.6',
#        '38.5', '57', '46.8', '11.9', '104', '53.8', '72.3', '94', '80.3',
#        '91', '109', '175.8', '59.2', '71.3', '100', '59.9', '61.7', '101',
#        '47.2', '51.9', '61.8', '75.4', '68.7', '50.7', '60.5', '74.2',
#        '102', '63.7', '55.7', '75.6', '118', '75', '63.5', '47.3', '44.4',
#        '30.1', '40.3', '35.1', '32.2', '38.3', '49.7', '9.2', '14.9',
#        '19.7', '90.7', '20.6', '23.5', '22.8', '39.9', '56.7', '35.9',
#        '47.4', '8.4', '7.7', '22.3', '8.5', '8.7', '9.8', '8.2', '40.8',
#        '58.6', '41.9', '34.9', '43.8', '46.2', '58.8', '37.9', '72.5',
#        '73', '56.4', '3', '190.3', '117', '88.8', '65.7', '85.7', '77.6',
#        '97.6', '196.9', '113', '63.3', '79.2', '80.1', '191', '67.8',
#        '184', '92.8', '84.8', '45.9', '44.8', '44.6', '94.9', '38.2',
#        '7.8', '55.8', '43.7', '76.9', '44.3', '57.1', '53.2', '45.2',
#        '51.8', '41.6', '42.8', '44.2', '50.1', '47.5', '86.3', '88.5',
#        '95', '75.8', '77', '56.9', '66', '49.6', '55.2', '32.9', '59.7',
#        '55.4', '53.7', '42.3', '22.7'], dtype=object)

# %% [markdown]
# ## Обработаем ceiling_height

# %%
Data_Purified["ceiling_height"] =  Data_Purified["ceiling_height"].str.replace('\xa0м' , "", regex=True).str.replace(",", ".")

# %%
Data_Purified["year_of_construction"].unique()
# Out:
# array(['1917', '1975', nan, '1968', '2009', '1969', '1980', '1990',
#        '1964', '2025', '2015', '1970', '1984', '1965', '2010', 'Аукцион',
#        '1992', '2011', '1986', '1994', '1956', '1966', '1973', '1971',
#        '1957', '2013', '1981', '1972', '1959', '2004', '1962', '2019',
#        '1978', '1977', '2003', '1963', '1952', '2024', '2007', '1995',
#        '1976', '1982', '1953', '2008', '2026', '2023', '1941', '2028',
#        '1993', '2016', '2027', '2017', '2022', '1932', '2012', '1960',
#        '2006', '1926', '2020', '1943', '2014', '2021', '1967', '1904',
#        '1991', '2018', '1987', '1988', '1974', 'Напишите автору', '1979',
#        '1929', '1989', '1985', '1930', '2005', '1958', '1996', '1940',
#        '1948', '1961', '1938', '1997', '2002', '2001', '1999', '1983',
#        '1998', '1902', '2000', '1915', '1910', '1939', '1954', '1897',
#        '1955', '1900', 'Позвоните автору', '1949', '1947', '1901', '1909',
#        '1600', '1951', '1936', '1931', '1950', '1934', '1928', '1945',
#        '1937', '1927', '1896', '1777', '2031', '1935'], dtype=object)

# %% [markdown]
# ## Заметим анамалии "Аукцион, Позвоните автору, Позвоните автору" обработаем и удалим  их

# %%
index = Data_Purified[Data_Purified["year_of_construction"].isin(["Аукцион", "Позвоните автору", "Напишите автору"])].index

# %%
Data_Purified = Data_Purified.drop(index)

# %%
Data_Purified["year_of_construction"].unique()
# Out:
# array(['1917', '1975', nan, '1968', '2009', '1969', '1980', '1990',
#        '1964', '2025', '2015', '1970', '1984', '1965', '2010', '1992',
#        '2011', '1986', '1994', '1956', '1966', '1973', '1971', '1957',
#        '2013', '1981', '1972', '1959', '2004', '1962', '2019', '1978',
#        '1977', '2003', '1963', '1952', '2024', '2007', '1995', '1976',
#        '1982', '1953', '2008', '2026', '2023', '1941', '2028', '1993',
#        '2016', '2027', '2017', '2022', '1932', '2012', '1960', '2006',
#        '1926', '2020', '1943', '2014', '2021', '1967', '1904', '1991',
#        '2018', '1987', '1988', '1974', '1979', '1929', '1989', '1985',
#        '1930', '2005', '1958', '1996', '1940', '1948', '1961', '1938',
#        '1997', '2002', '2001', '1999', '1983', '1998', '1902', '2000',
#        '1915', '1910', '1939', '1954', '1897', '1955', '1900', '1949',
#        '1947', '1901', '1909', '1600', '1951', '1936', '1931', '1950',
#        '1934', '1928', '1945', '1937', '1927', '1896', '1777', '2031',
#        '1935'], dtype=object)

# %% [markdown]
# ## Обработаем Пропуски

# %% [markdown]
# #### Обработаем Пропуски в колонках

# %% [markdown]
#  * parking_type
#  * underground
#  * have_loggia
#  * object_type

# %%
Data_Purified.head(8)
# Out:
#   floor floors_count rooms_count total_meters    price year_of_construction  \
# 0     6            6           1         20.7  2350000                 1917
# 1     1            9           1         33.0  4150000                 1975
# 2     4            4           1         14.0  1700000                  NaN
# 3     5            5           1         17.5  2500000                 1968
# 4     4            7           1         25.9  3000000                 2009
# 5     2            3           1         46.7  6599999                  NaN
# 6     3            5           1         29.0  3350000                 1917
# 7     3            6           1         19.1  3600000                 1917
#
#   object_type have_loggia parking_type living_meters kitchen_meters  \
# 0    Вторичка         NaN     Наземная            18              1
# 1    Вторичка         NaN          NaN            18              6
# 2    Вторичка         NaN          NaN           NaN            NaN
# 3    Вторичка         NaN          NaN           NaN            NaN
# 4    Вторичка         NaN     Наземная            20              5
# 5    Вторичка         NaN          NaN            25              6
# 6    Вторичка         NaN     Наземная            25            NaN
# 7    Вторичка         NaN          NaN           NaN            NaN
#
#   ceiling_height underground
# 0              3         NaN
# 1            2.7      Аннино
# 2            NaN         NaN
# 3            NaN         NaN
# 4            3.5         NaN
# 5            NaN         NaN
# 6              3         NaN
# 7            NaN         NaN

# %% [markdown]
# ##### Пропуски в процентном соотношении

# %%
Data_Purified[["parking_type", "underground", "have_loggia"]].isnull().mean()*100
# Out:
# parking_type    47.374101
# underground     34.280576
# have_loggia     46.486811
# dtype: float64

# %%
Data_Purified["parking_type"].unique()
# Out:
# array(['Наземная', nan, 'Многоуровневая', 'Подземная', 'Открытая'],
#       dtype=object)

# %%
Data_Purified["underground"].unique()
# Out:
# array([nan, 'Аннино', 'Силикатная', 'Поклонная', 'Белорусская',
#        'Бауманская', 'Тульская', 'Фили', 'Аэропорт', 'Улица 1905 года',
#        'Смоленская', 'Дмитровская', 'Давыдково', 'Маяковская', 'ЦСКА',
#        'Улица Академика Янгеля', 'Лермонтовский проспект',
#        'Зеленоград — Крюково', 'Говорово', 'Цветной бульвар', 'Ясенево',
#        'Преображенская площадь', 'Юго-Западная', 'Новые Черёмушки',
#        'Гражданская', 'Октябрьское поле', 'ЗИЛ', 'Орехово', 'Рассказовка',
#        'Арбатская', 'Аминьевская', 'Полянка', 'Кунцевская',
#        'Марьина Роща', 'Трубная', 'Речной вокзал', 'Павелецкая',
#        'Ломоносовский проспект', 'Молодёжная', 'Щукинская',
#        'Авиамоторная', 'Москва-Сити', 'Новокузнецкая', 'Алексеевская',
#        'Пушкинская', 'Сокольники', 'Нагатинская', 'Шелепиха',
#        'Сухаревская', 'Парк Победы', 'Крёкшино', 'Солнцево',
#        'Бунинская аллея', 'Кедровая', 'Филатов Луг', 'Щербинка',
#        'Новомосковская', 'Воронцовская', 'Парк Культуры', 'Фрунзенская',
#        'Сходненская', 'Соколиная гора', 'Ленинский проспект',
#        'Матвеевская', 'Потапово', 'Мичуринец', 'Красный Балтиец',
#        'Стахановская', 'Тёплый Стан', 'Хорошёвская', 'Краснопресненская',
#        'Спортивная', 'Савёловская', 'Кутузовская', 'Полежаевская',
#        'Серпуховская', 'Спартак', 'Сокол', 'Свиблово', 'Юго-Восточная',
#        'Народное Ополчение', 'Братиславская', 'Коптево', 'Ватутинки',
#        'Стрешнево', 'Марьино', 'Щёлковская', 'Пражская', 'Нижегородская',
#        'Площадь Гагарина', 'Летово', 'Апрелевка', 'Корниловская',
#        'Толстопальцево', 'Окружная', 'Румянцево', 'Новопеределкино',
#        'Пятницкое шоссе', 'Кузьминки', 'Прокшино', 'Некрасовка',
#        'Медведково', 'Новокосино', 'Каширская', 'Отрадное', 'Крымская',
#        'Достоевская', 'Никольское', 'Реутов', 'Одинцово', 'Люберцы',
#        'Панки', 'Лухмановская', 'Академическая', 'Приморская', 'Курская',
#        'Чкаловская', 'Верхние Лихоборы', 'Ховрино', 'Проспект Ветеранов',
#        'Шаболовская', 'Динамо', 'Технопарк', 'Рабочий посёлок',
#        'Площадь Маркса', 'Комендантский проспект', 'Китай-город',
#        'Новослободская', 'Дубровка', 'Лесная', 'ВДНХ', 'Серебряный Бор',
#        'Славянский бульвар', 'Деловой центр', 'Дубравная',
#        'Москва-Товарная', 'Ломоносовская', 'Алма-Атинская',
#        'Железнодорожная', 'Фонвизинская', 'Крестовский остров',
#        'Хлебниково', 'Долгопрудная', 'Водники', 'Селигерская',
#        'Коломенская', 'Боровицкая', 'Верхние котлы', 'Ольховая',
#        'Филёвский парк', 'Кантемировская', 'Площадь Революции', 'Раменки',
#        'Киевская', 'Тушинская', 'Кропоткинская', 'Саларьево',
#        'Водный стадион', 'Лобня', 'Планерная', 'Сходня', 'Подрезково',
#        'Молжаниново', 'Шереметьевская', 'Химки', 'Новоподрезково',
#        'Левобережная', 'Перово', 'Угрешская', 'Электрозаводская',
#        'Кузнецкий мост', 'Южная', 'Кавказский бульвар', 'Первомайская',
#        'Профсоюзная', 'Воробьёвы горы', 'Минская', 'Люблино', 'Мнёвники',
#        'Мичуринский проспект', 'Ботанический сад', 'Москворечье',
#        'Домодедовская', 'Зюзино', 'Тропарёво', 'Красносельская',
#        'Озёрная', 'Бульвар Генерала Карбышева', 'Беломорская', 'Нагорная',
#        'Пыхтино', 'Тургеневская', 'Варшавская', 'Владыкино', 'Ростокино',
#        'Комсомольская', 'Алтуфьево', 'Физтех', 'Кокошкино', 'Новогиреево',
#        'Тверская', 'Беговая', 'Менделеевская', 'Семёновская',
#        'Автозаводская', 'Крестьянская застава', 'Волоколамская',
#        'Трикотажная', 'Новаторская', 'Площадь Ильича', 'Калитники',
#        'Салтыковская', 'Кучино', 'Ольгино', 'Остафьево', 'Подольск',
#        'Раменское', 'Есенинская', 'Фабричная', 'Ипподром', 'Павшино',
#        'Бутово', 'Красногорская', 'Новодачная', 'Площадь 1905 года',
#        'Пионерская', 'Козья слобода', 'Бабушкинская', 'Горки',
#        'Серп и Молот', 'Терехово ', 'Кремлёвская', 'Рыбацкое',
#        'Авиастроительная', 'Северный Вокзал', 'Ладожская', 'Яшьлек',
#        'Проспект Победы', 'Новочеркасская', 'Проспект Большевиков',
#        'Парнас', 'Выборгская', 'Черная речка', 'Студенческая',
#        'Площадь Ленина', 'Улица Дыбенко', 'Московские ворота',
#        'Гагаринская', 'Кировский завод', 'Горьковская', 'Площадь Тукая',
#        'Горный институт', 'Сколково', 'Липовая Роща', 'Лубянка',
#        'Безымянка', 'Девяткино', 'Технологический институт', 'Ильинская',
#        'Елизаровская', 'Балтийская', 'Звездная', 'Алабинская', 'Купчино',
#        'Аметьево', 'Строгино', 'Победа', 'Курьяново', 'Зорге',
#        'Черкизовская', 'Третьяковская', 'Пролетарская',
#        'Улица Милашенкова', 'Красные ворота', 'Перерва', 'Кожуховская',
#        'Хорошёво', 'Октябрьская', 'Театральная', 'Панфиловская',
#        'Бутырская', 'Университет', 'Машиностроителей', 'Удельная',
#        'Опалиха', 'Царицыно', 'Василеостровская', 'Бульвар Рокоссовского',
#        'Площадь Мужества', 'Бачуринская', 'Гражданский проспект',
#        'Заельцовская', 'Ботаническая', 'Котельники', 'Выхино',
#        'Грачёвская', 'Гольяново', 'Улица Сергея Эйзенштейна',
#        'Партизанская', 'Битца', 'Бирюлёво', 'Коньково', 'Крылатское',
#        'Нахабино', 'Ухтомская', 'Жулебино', 'Проспект Просвещения',
#        'Митино', 'Обводный канал', 'Площадь Восстания', 'Чернышевская',
#        'Гостиный двор', 'Севастопольская', 'Автово', 'Геологическая',
#        'Юнгородок', 'Отдых', 'Внуково', 'Нарвская', 'Волковская',
#        'Шушары', 'Фирсановская', 'Марк', 'Пенягино', 'Аникеевка',
#        'Мякинино', 'Белокаменная'], dtype=object)

# %%
Data_Purified["object_type"].unique()
# Out:
# array(['Вторичка', 'Новостройка', 'Вторичка / Апартаменты',
#        'Новостройка / Апартаменты', 'Вторичка / Пентхаус',
#        'Новостройка / Пентхаус', nan], dtype=object)

# %% [markdown]
# ### В Колонках "parking_type", "underground", "have_loggia" пропуски заменим на "нет" так как есть дома без парковки, квартиры без лоджи и не везде близко метро

# %%
Data_Purified["parking_type"] = Data_Purified["parking_type"].fillna("0")

# %% [markdown]
# #### В колонке underground переведём данные в 0-1 есть метро или попросту отсуствует

# %%
Data_Purified["underground"] = Data_Purified["underground"].apply( lambda x : 0 if pd.isna(x) else 1)

# %%
Data_Purified["have_loggia"]  = Data_Purified["have_loggia"].fillna("0")

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# #### Обработаем Пропуски в колонках

# %% [markdown]
# * floor
# * floors_count
# * rooms_count

# %%
Data_Purified[["floor", "floors_count","rooms_count"] ].describe()
# Out:
#              floor  floors_count  rooms_count
# count  8337.000000   8337.000000  8337.000000
# mean      7.335372     13.998681     1.667866
# std       6.418490      8.987762     0.827876
# min       1.000000      1.000000     1.000000
# 25%       3.000000      8.000000     1.000000
# 50%       6.000000     14.000000     1.000000
# 75%      10.000000     17.000000     2.000000
# max      82.000000     97.000000     5.000000

# %% [markdown]
# #### Пропуски в коолонки floor, rooms_count, floors_count заполним с помощью sklearn.impute.SimpleImputer. средними значениями

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
categorical_columns = ["floor", "floors_count", "rooms_count"]
Data_Purified[categorical_columns] = imputer.fit_transform(Data_Purified[categorical_columns].values)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# ## Рассмотрим колонкии
#  * total_meters Площадь квартиры,
#  * living_meters-жилая площадь
#  * kitchen_meters - площадь кухни

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340 entries, 0 to 8392
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 8340 non-null   float64
#  1   floors_count          8340 non-null   float64
#  2   rooms_count           8340 non-null   float64
#  3   total_meters          7853 non-null   object
#  4   price                 7840 non-null   object
#  5   year_of_construction  6484 non-null   object
#  6   object_type           7853 non-null   object
#  7   have_loggia           8340 non-null   object
#  8   parking_type          8340 non-null   object
#  9   living_meters         6078 non-null   object
#  10  kitchen_meters        6503 non-null   object
#  11  ceiling_height        5101 non-null   object
#  12  underground           8340 non-null   int64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 912.2+ KB

# %%
Data_Purified[["total_meters", "living_meters", "kitchen_meters"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340 entries, 0 to 8392
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_meters    7853 non-null   object
#  1   living_meters   6078 non-null   object
#  2   kitchen_meters  6503 non-null   object
# dtypes: object(3)
# memory usage: 260.6+ KB

# %% [markdown]
# #### Пропуски в процентном соотношении

# %%
Data_Purified[["total_meters","kitchen_meters", "living_meters" ]].isnull().mean()*100
# Out:
# total_meters       5.839329
# kitchen_meters    22.026379
# living_meters     27.122302
# dtype: float64

# %% [markdown]
# ### Взглянем на среднее значения total_meters

# %% [markdown]
# ### Среднее значение столбцов боле 50% заполним пропуски среднем значением

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
categorical_columns = ["kitchen_meters", "living_meters", "total_meters"]
Data_Purified[categorical_columns] = imputer.fit_transform(Data_Purified[categorical_columns].values)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='cividis')
# Out:
# <Axes: >

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340 entries, 0 to 8392
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 8340 non-null   float64
#  1   floors_count          8340 non-null   float64
#  2   rooms_count           8340 non-null   float64
#  3   total_meters          8340 non-null   float64
#  4   price                 7840 non-null   object
#  5   year_of_construction  6484 non-null   object
#  6   object_type           7853 non-null   object
#  7   have_loggia           8340 non-null   object
#  8   parking_type          8340 non-null   object
#  9   living_meters         8340 non-null   float64
#  10  kitchen_meters        8340 non-null   float64
#  11  ceiling_height        5101 non-null   object
#  12  underground           8340 non-null   int64
# dtypes: float64(6), int64(1), object(6)
# memory usage: 912.2+ KB

# %%
colum_didgit = ["floor", "floors_count", "rooms_count", "price", "year_of_construction", "ceiling_height"]

Data_Purified[colum_didgit] = Data_Purified[colum_didgit].fillna(0).astype(float).astype(int)

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8340 entries, 0 to 8392
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 8340 non-null   int32
#  1   floors_count          8340 non-null   int32
#  2   rooms_count           8340 non-null   int32
#  3   total_meters          8340 non-null   float64
#  4   price                 8340 non-null   int32
#  5   year_of_construction  8340 non-null   int32
#  6   object_type           7853 non-null   object
#  7   have_loggia           8340 non-null   object
#  8   parking_type          8340 non-null   object
#  9   living_meters         8340 non-null   float64
#  10  kitchen_meters        8340 non-null   float64
#  11  ceiling_height        8340 non-null   int32
#  12  underground           8340 non-null   int64
# dtypes: float64(3), int32(6), int64(1), object(3)
# memory usage: 716.7+ KB

# %% [markdown]
# #### Взглянем на ceiling_height

# %%
Data_Purified["ceiling_height"].describe()
# Out:
# count    8340.000000
# mean        1.381175
# std         1.308291
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         2.000000
# max        52.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# #### Выведем 4 максимальных значения -ceiling_height

# %%
Data_Purified.loc[Data_Purified['ceiling_height'].nlargest(4).index]
# Out:
#       floor  floors_count  rooms_count  total_meters     price  \
# 2250      1             2            2          58.3   5700000
# 5121      5             5            1          31.9   3850000
# 5293      1             9            2          49.0   5449000
# 225       3            13            1          47.0  23876000
#
#       year_of_construction  object_type have_loggia parking_type  \
# 2250                  1955     Вторичка           0            0
# 5121                  1995     Вторичка    1 балкон     Наземная
# 5293                  1990     Вторичка    1 балкон     Наземная
# 225                   2025  Новостройка    1 балкон    Подземная
#
#       living_meters  kitchen_meters  ceiling_height  underground
# 2250           40.0             6.0              52            1
# 5121           17.7             5.3              25            0
# 5293           27.0             9.0               9            1
# 225            14.3            15.0               6            1

# %% [markdown]
# Строчки с индексами 2250 5121 скорее анамалии удалим их

# %%
Data_Purified.drop(2250, inplace= True)

# %%
Data_Purified.drop(5121, inplace= True)

# %%
Data_Purified["ceiling_height"].describe()
# Out:
# count    8338.000000
# mean        1.372272
# std         1.156593
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%         2.000000
# max         9.000000
# Name: ceiling_height, dtype: float64

# %%
Data_Purified["ceiling_height"] = Data_Purified["ceiling_height"].fillna(Data_Purified["ceiling_height"].mean()).round(2)

# %%
Data_Purified["ceiling_height"].isnull().mean()*100
# Out:
# 0.0

# %% [markdown]
# Рассмотрим Price

# %%
Data_Purified["price"] = Data_Purified["price"].round(2)

# %%
Data_Purified["price"].isnull().mean()*100
# Out:
# 0.0

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(Data_Purified['price'])
plt.title("price")
plt.ylabel("price")
plt.show()

# %%
Data_Purified.loc[Data_Purified['price'].nlargest(4).index]
# Out:
#       floor  floors_count  rooms_count  total_meters       price  \
# 5853     66            66            5         588.1  1058580000
# 5845     12            14            5         227.4   834760000
# 1172     10            11            5         352.0   704140000
# 1153      8             9            4         247.3   666993329
#
#       year_of_construction                object_type have_loggia  \
# 5853                  2020  Новостройка / Апартаменты           0
# 5845                  2024                Новостройка    1 балкон
# 1172                  2024                Новостройка           0
# 1153                  2023     Вторичка / Апартаменты           0
#
#      parking_type  living_meters  kitchen_meters  ceiling_height  underground
# 5853            0      27.258128       10.512563               3            1
# 5845    Подземная      85.700000       55.100000               3            1
# 1172            0      27.258128       10.512563               0            1
# 1153            0      27.258128       10.512563               3            1

# %%
Data_Purified.drop(index = 5853, inplace= True  )

# %%
Data_Purified.drop(1172, inplace= True)

# %%
Data_Purified["price"].isnull().mean()*100
# Out:
# 0.0

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(Data_Purified['price'])
plt.title("price")
plt.ylabel("price")
plt.show()

# %%
Data_Purified.nsmallest(4, "price")
# Out:
#       floor  floors_count  rooms_count  total_meters       price  \
# 5851      5             5            5         590.3 -2147483648
# 115       8            59            3          56.1           0
# 499       2            24            1          36.3           0
# 579       2            59            2          31.1           0
#
#       year_of_construction  object_type have_loggia parking_type  \
# 5851                  2027  Новостройка           0            0
# 115                   2028  Новостройка           0            0
# 499                   2025  Новостройка           0    Подземная
# 579                   2028  Новостройка           0            0
#
#       living_meters  kitchen_meters  ceiling_height  underground
# 5851      27.258128       10.512563               3            1
# 115       36.100000       10.512563               2            1
# 499       21.800000       10.512563               2            1
# 579       15.700000       10.512563               2            1

# %%
Data_Purified.drop(5851, inplace=True)

# %% [markdown]
# Заметим в Price 0 значение. Квартира не может стоить 0 по этому удалим строчки с нулевым значением

# %%
Data_Purified = Data_Purified[Data_Purified['price'] != 0]

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(Data_Purified['price'])
plt.title("price")
plt.ylabel("price")
plt.show()

# %%
Data_Purified.drop(index = 5845, inplace= True  )

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(Data_Purified['price'])
plt.title("price")
plt.ylabel("price")
plt.show()

# %% [markdown]
# # Ближе к реальному положению

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='cividis')
# Out:
# <Axes: >

# %% [markdown]
# #### Процент пропуска в object_type

# %%
Data_Purified["object_type"].isnull().mean()*100
# Out:
# 0.0

# %% [markdown]
# #### Взглянем на уникальные значения object_type

# %%
Data_Purified["object_type"].unique()
# Out:
# array(['Вторичка', 'Новостройка', 'Вторичка / Апартаменты',
#        'Новостройка / Апартаменты', 'Вторичка / Пентхаус',
#        'Новостройка / Пентхаус'], dtype=object)

# %% [markdown]
# #### Обработаем колонку object_type, что бы остался только "Вторичка, Новостройка"

# %%
def proccessing_obgect_tipe(val):
    if isinstance(val, str):
        if val == "Вторичка":
            return val
        elif val == "Новостройка":
            return val 
        elif val == 'Вторичка / Апартаменты':
            return "Вторичка"
        elif val == 'Новостройка / Апартаменты':
            return "Новостройка"
        elif val == 'Вторичка / Пентхаус':
            return "Вторичка"
        elif val == "Новостройка / Пентхаус":
            return "Новостройка"
    else:
        return val

# %%
Data_Purified["object_type"] = Data_Purified["object_type"].apply(proccessing_obgect_tipe)

# %%
Data_Purified["object_type"].unique()
# Out:
# array(['Вторичка', 'Новостройка'], dtype=object)

# %% [markdown]
# #### Процент пропуска мал но для чиcтоты удалии пропуски

# %%
index_drop = Data_Purified[Data_Purified["object_type"].isnull()].index

# %%
Data_Purified.drop(index_drop , inplace= True)

# %%
Data_Purified["object_type"].unique()
# Out:
# array(['Вторичка', 'Новостройка'], dtype=object)

# %% [markdown]
# ### Пройдёмся по колонке object_type перевидём в булевую константу 0-Вторичка, 1- Новостройка

# %%
Data_Purified["object_type"] = Data_Purified["object_type"].apply(lambda x : 0 if x == "Вторичка" else 1)

# %%
Data_Purified["object_type"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### Посмотрим колонку year_of_construction

# %%
Data_Purified["year_of_construction"]
# Out:
# 0       1917
# 1       1975
# 2          0
# 3       1968
# 4       2009
#         ...
# 8388    2018
# 8389    2025
# 8390    1968
# 8391    2023
# 8392    2025
# Name: year_of_construction, Length: 7834, dtype: int32

# %%
plt.figure(figsize=(30, 6))
plt.hist(Data_Purified["year_of_construction"], bins=50, edgecolor='k') 
plt.title('year_of_construction')
plt.xlabel('Значение')
plt.ylabel('год')
plt.show()

# %% [markdown]
# Нас интересуют постройки приблежённые к нашему периоду возьмём переод с 1990 года по нынешний  2024

# %%
Data_Purified = Data_Purified[(Data_Purified["year_of_construction"] > 1990) & (Data_Purified["year_of_construction"] <= 2024)]

# %%
plt.figure(figsize=(30, 6))
plt.hist(Data_Purified["year_of_construction"], bins=50, edgecolor='k') 
plt.title('year_of_construction')
plt.xlabel('Значение')
plt.ylabel('год')
plt.show()

# %% [markdown]
# #### Более приблежённые к реальности

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3438 entries, 4 to 8391
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 3438 non-null   int32
#  1   floors_count          3438 non-null   int32
#  2   rooms_count           3438 non-null   int32
#  3   total_meters          3438 non-null   float64
#  4   price                 3438 non-null   int32
#  5   year_of_construction  3438 non-null   int32
#  6   object_type           3438 non-null   int64
#  7   have_loggia           3438 non-null   object
#  8   parking_type          3438 non-null   object
#  9   living_meters         3438 non-null   float64
#  10  kitchen_meters        3438 non-null   float64
#  11  ceiling_height        3438 non-null   int32
#  12  underground           3438 non-null   int64
# dtypes: float64(3), int32(6), int64(2), object(2)
# memory usage: 295.5+ KB

# %%
Data_Purified.isnull().mean()*100
# Out:
# floor                   0.0
# floors_count            0.0
# rooms_count             0.0
# total_meters            0.0
# price                   0.0
# year_of_construction    0.0
# object_type             0.0
# have_loggia             0.0
# parking_type            0.0
# living_meters           0.0
# kitchen_meters          0.0
# ceiling_height          0.0
# underground             0.0
# dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(Data_Purified.isnull(),cmap='ocean')
# Out:
# <Axes: >

# %% [markdown]
# #### Пропуски отсутствуют

# %% [markdown]
# #### Добавим дополнительную колонку

# %%
Data_Purified["price_meter"] = Data_Purified["price"] // Data_Purified["total_meters"]

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3438 entries, 4 to 8391
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 3438 non-null   int32
#  1   floors_count          3438 non-null   int32
#  2   rooms_count           3438 non-null   int32
#  3   total_meters          3438 non-null   float64
#  4   price                 3438 non-null   int32
#  5   year_of_construction  3438 non-null   int32
#  6   object_type           3438 non-null   int64
#  7   have_loggia           3438 non-null   object
#  8   parking_type          3438 non-null   object
#  9   living_meters         3438 non-null   float64
#  10  kitchen_meters        3438 non-null   float64
#  11  ceiling_height        3438 non-null   int32
#  12  underground           3438 non-null   int64
#  13  price_meter           3438 non-null   float64
# dtypes: float64(4), int32(6), int64(2), object(2)
# memory usage: 322.3+ KB

# %%
Data_Purified["price_meter"] = Data_Purified["price_meter"].apply(int)

# %%
Data_Purified["year_of_construction"] = Data_Purified["year_of_construction"].apply(int)

# %% [markdown]
# #### Колонки
#
#
# * have_loggia
# * parking_type
#
# имеют тип Object Проработаем их

# %%
Data_Purified["parking_type"].value_counts()
# Out:
# parking_type
# Наземная          1428
# 0                 1266
# Подземная          475
# Открытая           153
# Многоуровневая     116
# Name: count, dtype: int64

# %%
Data_Purified["have_loggia"].value_counts()
# Out:
# have_loggia
# 1 лоджия               1252
# 0                      1199
# 1 балкон                649
# 2 лоджии                142
# 1 лоджия, 1 балкон       92
# 2 балкона                58
# 3 лоджии                 14
# 3 балкона                11
# 1 лоджия, 2 балкона       7
# 2 лоджии, 1 балкон        6
# 4 лоджии                  4
# 2 лоджии, 2 балкона       3
# 4 балкона                 1
# Name: count, dtype: int64

# %%
from sklearn import preprocessing

columns = ['have_loggia', 'parking_type']

for col in columns:
  le = preprocessing.LabelEncoder()
  Data_Purified[col] = le.fit_transform(Data_Purified[col])
  integer_mapping = {l: i for i, l in enumerate(le.classes_)}

# %%
Data_Purified["have_loggia"].unique()
# Out:
# array([ 0,  2,  1,  6,  5,  9,  3, 11,  4,  7, 10,  8, 12])

# %%
Data_Purified["parking_type"].unique()
# Out:
# array([2, 0, 1, 4, 3])

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3438 entries, 4 to 8391
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 3438 non-null   int32
#  1   floors_count          3438 non-null   int32
#  2   rooms_count           3438 non-null   int32
#  3   total_meters          3438 non-null   float64
#  4   price                 3438 non-null   int32
#  5   year_of_construction  3438 non-null   int64
#  6   object_type           3438 non-null   int64
#  7   have_loggia           3438 non-null   int32
#  8   parking_type          3438 non-null   int32
#  9   living_meters         3438 non-null   float64
#  10  kitchen_meters        3438 non-null   float64
#  11  ceiling_height        3438 non-null   int32
#  12  underground           3438 non-null   int64
#  13  price_meter           3438 non-null   int64
# dtypes: float64(3), int32(7), int64(4)
# memory usage: 308.9 KB

# %% [markdown]
# #### Проверим Данные на предмет анамалий с помощью Блоксплота

# %%
colms = Data_Purified[['price', 'living_meters', 'floor', 'kitchen_meters', 'floors_count', 'total_meters' ]]
fig, axes = plt.subplots(nrows = 3, ncols = 3, figsize = (15, 15))

for i, column in enumerate(colms):
  row = i//3
  col = i % 3
  sns.boxplot(x=colms[column], ax = axes[row, col], color = 'red')
  axes[row, col].set_title(f'{column} boxplot')

plt.subplots_adjust(hspace = 0.9)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(x=Data_Purified['price'], color = 'red')
# Out:
# <Axes: xlabel='price'>

# %%
Data_Purified.loc[Data_Purified['price'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 1153      8             9            4        247.30  666993329
# 2991      5             6            4        203.27  650560000
# 5838     21            21            5        363.30  629417250
# 2998      4             4            4        288.00  574431000
# 3056      5            14            4        198.40  557450000
# 5839     11            12            5        303.00  531661349
# 1157     11            13            5        265.60  405328840
# 5837     11            13            5        265.60  405328840
# 1134     18            21            4        234.30  344593211
# 5849      6             6            5        310.15  325657500
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 1153                  2023            0            0             0
# 2991                  2024            1            0             0
# 5838                  2023            1            0             4
# 2998                  2024            0            5             0
# 3056                  2024            1            5             4
# 5839                  2014            0            1             4
# 1157                  2024            1            0             0
# 5837                  2024            1            0             0
# 1134                  2023            1            0             0
# 5849                  2023            0            0             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 1153      27.258128       10.512563               3            1      2697102
# 2991      27.258128       10.512563               0            1      3200472
# 5838     190.300000       31.400000               0            1      1732499
# 2998      27.258128       20.000000               3            1      1994552
# 3056      75.600000       55.000000               3            1      2809727
# 5839     117.000000       24.000000               3            1      1754657
# 1157      27.258128       10.512563               3            1      1526087
# 5837      27.258128       10.512563               3            1      1526087
# 1134      27.258128       27.100000               3            1      1470735
# 5849     196.900000       22.700000               4            1      1050000

# %%
sns.boxplot(x=Data_Purified['price'], color = 'red')
# Out:
# <Axes: xlabel='price'>

# %%
Data_Purified["living_meters"].describe()
# Out:
# count    3438.000000
# mean       28.558886
# std        15.804258
# min         3.000000
# 25%        18.400000
# 50%        27.258128
# 75%        33.000000
# max       300.000000
# Name: living_meters, dtype: float64

# %%
Data_Purified.loc[Data_Purified['living_meters'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 1164     23            24            5        415.00  150000000
# 5849      6             6            5        310.15  325657500
# 5861     60            75            5        294.70  294700000
# 5838     21            21            5        363.30  629417250
# 2984     82            85            4        285.00  251000000
# 1158     26            31            5        246.70  288063785
# 1161      3             9            5        234.80  125000000
# 5854     57            75            5        304.00  260000000
# 155      37            85            3        187.50  150562821
# 167      34            57            3        177.00  150000000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 1164                  1998            0            6             4
# 5849                  2023            0            0             4
# 5861                  2015            0            0             4
# 5838                  2023            1            0             4
# 2984                  2016            0            0             4
# 1158                  2008            0            9             4
# 1161                  1999            0            4             4
# 5854                  2010            0            0             0
# 155                   2015            1            0             0
# 167                   2006            0            0             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 1164          300.0       74.000000               3            1       361445
# 5849          196.9       22.700000               4            1      1050000
# 5861          191.0       46.000000               5            1      1000000
# 5838          190.3       31.400000               0            1      1732499
# 2984          175.8       15.400000               4            1       880701
# 1158          140.9       28.000000               3            1      1167668
# 1161          140.0       23.000000               0            1       532367
# 5854          140.0       90.000000               3            1       855263
# 155           139.1       10.512563               0            1       803001
# 167           138.0       21.000000               3            1       847457

# %%
sns.boxplot(x=Data_Purified['living_meters'], color = 'blue')
# Out:
# <Axes: xlabel='living_meters'>

# %%
Data_Purified = Data_Purified[Data_Purified['living_meters'] < 140]

# %%
sns.boxplot(x=Data_Purified['living_meters'], color = 'red')
# Out:
# <Axes: xlabel='living_meters'>

# %%
sns.boxplot(x=Data_Purified['floor'], color = 'blue')
# Out:
# <Axes: xlabel='floor'>

# %%
Data_Purified.loc[Data_Purified['floor'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 617      75            95            1         57.00   47000000
# 923      75            95            1         57.00   47000000
# 3615     75            95            1         57.00   47000000
# 6688     75            95            1         57.00   47000000
# 1162     57            76            5        303.40  260000000
# 1116     48            53            1         47.50   21549040
# 2981     47            55            4        108.36   50000000
# 3956     40            68            2         60.00   53000000
# 1144     38            41            4        117.83   96620600
# 1834     38            44            2         49.50   42500000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 617                   2017            0            0             4
# 923                   2017            0            0             4
# 3615                  2017            0            0             4
# 6688                  2017            0            0             4
# 1162                  2008            0            0             4
# 1116                  2024            1            0             0
# 2981                  2024            1            0             0
# 3956                  2020            0            0             4
# 1144                  2024            1            0             0
# 1834                  2018            0            0             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 617       37.000000       10.000000               3            1       824561
# 923       37.000000       10.000000               3            1       824561
# 3615      37.000000       10.000000               3            1       824561
# 6688      37.000000       10.000000               3            1       824561
# 1162      27.258128       10.512563               3            1       856954
# 1116      27.258128       10.512563               3            1       453664
# 2981      27.258128       10.512563               3            1       461424
# 3956      40.000000       10.000000               0            1       883333
# 1144     112.800000       10.512563               3            1       820000
# 1834      32.000000        7.000000               0            1       858585

# %%
Data_Purified['floor'].describe()
# Out:
# count    3430.000000
# mean        8.499708
# std         6.582972
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        12.000000
# max        75.000000
# Name: floor, dtype: float64

# %%
Data_Purified = Data_Purified[Data_Purified["floor"] < 40]

# %%
sns.boxplot(x=Data_Purified['floor'], color = 'red')
# Out:
# <Axes: xlabel='floor'>

# %%
Data_Purified['floor'] = Data_Purified['floor'].astype(int)

# %%
sns.boxplot(x=Data_Purified['kitchen_meters'], color = 'red')
# Out:
# <Axes: xlabel='kitchen_meters'>

# %%
Data_Purified.loc[Data_Purified['kitchen_meters'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 1724      1             4            2         151.6  227400000
# 3056      5            14            4         198.4  557450000
# 1141      4            12            4         148.7   96000000
# 1151      7             8            4         199.8  110000000
# 1178     16            16            5         269.0   95000000
# 2994     25            26            4         250.0   64849000
# 6475      4            19            3         101.0   14500000
# 839       7            23            3         127.8   27000000
# 5274     14            20            3         149.3   22245700
# 7503      7            23            3         127.8   27000000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 1724                  2017            0            0             4
# 3056                  2024            1            5             4
# 1141                  2019            0            0             0
# 1151                  2001            0            0             4
# 1178                  1999            0            8             4
# 2994                  2005            0            2             4
# 6475                  2011            0            6             4
# 839                   2012            0            0             4
# 5274                  2023            1            6             0
# 7503                  2012            0            0             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 1724      50.000000            65.0               3            1      1500000
# 3056      75.600000            55.0               3            1      2809727
# 1141      27.258128            51.4               0            1       645595
# 1151      27.258128            50.0               3            1       550550
# 1178      27.258128            50.0               3            1       353159
# 2994     100.000000            50.0               3            1       259396
# 6475      27.258128            50.0               2            1       143564
# 839       51.400000            49.2               3            1       211267
# 5274      57.300000            49.2               3            1       148999
# 7503      51.400000            49.2               3            1       211267

# %%
Data_Purified = Data_Purified[Data_Purified['kitchen_meters'] < 40]

# %%
sns.boxplot(x=Data_Purified['kitchen_meters'], color = 'blue')
# Out:
# <Axes: xlabel='kitchen_meters'>

# %%
sns.boxplot(x=Data_Purified['floors_count'], color = 'red')
# Out:
# <Axes: xlabel='floors_count'>

# %%
Data_Purified.loc[Data_Purified['floors_count'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 155      37            85            3         187.5  150562821
# 220      30            79            1          78.0   92880000
# 3483     30            79            1          78.0   92880000
# 4208     30            79            1          78.0   92880000
# 6760     30            79            1          78.0   92880000
# 211      16            78            2          62.0   42000000
# 188       9            68            2          92.0  110000000
# 3947     31            65            2          51.1   50000000
# 167      34            57            3         177.0  150000000
# 2992      6            56            4         110.1   43100060
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 155                   2015            1            0             0
# 220                   2019            0            0             4
# 3483                  2019            0            0             4
# 4208                  2019            0            0             4
# 6760                  2019            0            0             4
# 211                   2020            0            0             0
# 188                   2020            0            0             4
# 3947                  2021            0            0             4
# 167                   2006            0            0             4
# 2992                  2024            1            0             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 155      139.100000       10.512563               0            1       803001
# 220       50.000000       15.000000               0            1      1190769
# 3483      50.000000       15.000000               0            1      1190769
# 4208      50.000000       15.000000               0            1      1190769
# 6760      50.000000       15.000000               0            1      1190769
# 211       27.258128       10.512563               3            1       677419
# 188       54.000000       10.512563               0            1      1195652
# 3947      27.258128       10.512563               3            1       978473
# 167      138.000000       21.000000               3            1       847457
# 2992      71.300000        6.100000               3            1       391462

# %%
Data_Purified = Data_Purified[Data_Purified['floors_count'] < 50]

# %%
sns.boxplot(x=Data_Purified['floors_count'], color = 'blue')
# Out:
# <Axes: xlabel='floors_count'>

# %%
sns.boxplot(x=Data_Purified['total_meters'], color = 'blue')
# Out:
# <Axes: xlabel='total_meters'>

# %%
Data_Purified.loc[Data_Purified['total_meters'].nlargest(10).index]
# Out:
#       floor  floors_count  rooms_count  total_meters      price  \
# 5867      1             7            5         398.1  170000000
# 5839     11            12            5         303.0  531661349
# 2998      4             4            4         288.0  574431000
# 2644      1             2            3         276.9   29999999
# 1157     11            13            5         265.6  405328840
# 5837     11            13            5         265.6  405328840
# 1173      2             8            5         250.0  225000000
# 3011     17            17            4         250.0  160000000
# 1153      8             9            4         247.3  666993329
# 3054     21            23            4         244.1   78000000
#
#       year_of_construction  object_type  have_loggia  parking_type  \
# 5867                  2005            0            0             0
# 5839                  2014            0            1             4
# 2998                  2024            0            5             0
# 2644                  1991            0            0             0
# 1157                  2024            1            0             0
# 5837                  2024            1            0             0
# 1173                  2010            0            0             4
# 3011                  2006            0            0             0
# 1153                  2023            0            0             0
# 3054                  2007            0            8             4
#
#       living_meters  kitchen_meters  ceiling_height  underground  price_meter
# 5867      27.258128       20.000000               3            1       427028
# 5839     117.000000       24.000000               3            1      1754657
# 2998      27.258128       20.000000               3            1      1994552
# 2644      62.000000       30.700000               2            1       108342
# 1157      27.258128       10.512563               3            1      1526087
# 5837      27.258128       10.512563               3            1      1526087
# 1173      27.258128       20.000000               3            1       900000
# 3011      27.258128       10.512563               3            1       640000
# 1153      27.258128       10.512563               3            1      2697102
# 3054      27.258128       10.512563               3            1       319541

# %%
Data_Purified = Data_Purified[Data_Purified['total_meters'] < 200]

# %%
sns.boxplot(x=Data_Purified['total_meters'], color = 'red')
# Out:
# <Axes: xlabel='total_meters'>

# %%
Data_Purified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3376 entries, 4 to 8391
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   floor                 3376 non-null   int32
#  1   floors_count          3376 non-null   int64
#  2   rooms_count           3376 non-null   int32
#  3   total_meters          3376 non-null   float64
#  4   price                 3376 non-null   int32
#  5   year_of_construction  3376 non-null   int64
#  6   object_type           3376 non-null   int64
#  7   have_loggia           3376 non-null   int32
#  8   parking_type          3376 non-null   int32
#  9   living_meters         3376 non-null   float64
#  10  kitchen_meters        3376 non-null   float64
#  11  ceiling_height        3376 non-null   int32
#  12  underground           3376 non-null   int64
#  13  price_meter           3376 non-null   int64
# dtypes: float64(3), int32(6), int64(5)
# memory usage: 316.5 KB

# %% [markdown]
# ## Графики

# %%
plt.figure(figsize = (15,10))
sns.heatmap(Data_Purified.corr(), cmap = 'flare', annot = True)
plt.title('Матрица корреляции')
# Out:
# Text(0.5, 1.0, 'Матрица корреляции')

# %% [markdown]
# #### График 1: Распределение цен на квартиры

# %% [markdown]
# ### Влияние площади квартиры на цену График, отображающий связь между площадью и ценой, поможет понять, как площадь влияет на стоимость.

# %%
plt.figure(figsize=(10, 6))
plt.hist(Data_Purified['price'], bins=30, edgecolor='black', alpha=0.7)
plt.title('Распределение цен на квартиры')
plt.xlabel('Цена')
plt.ylabel('Частота')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Влияние количества комнат на цену за квадратный метр Этот график позволяет оценить, как меняется цена за квадратный метр в зависимости от количества комнат.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Data_Purified['total_meters'], Data_Purified['price'], alpha=0.5)
plt.title('Влияние площади квартиры на цену')
plt.xlabel('Общая площадь (м²)')
plt.ylabel('Цена')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Влияние года постройки на цену График показывает влияние года постройки на цену, что дает представление о тенденциях стоимости по годам

# %%
sns.boxplot(x='rooms_count', y='price_meter', data=Data_Purified)
plt.title('Цена за квадратный метр в зависимости от количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Цена за квадратный метр')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Зависимость цены от этажа Показывает, как цена может меняться в зависимости от этажа, на котором расположена квартира.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Data_Purified['year_of_construction'], Data_Purified['price'], alpha=0.5)
plt.title('Влияние года постройки на цену')
plt.xlabel('Год постройки')
plt.ylabel('Цена')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='floor', y='price', data=Data_Purified)
plt.title('Цена в зависимости от этажа')
plt.xlabel('Этаж')
plt.ylabel('Цена')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Колонка Price больше нам не нужна удалим её и подготовим данные для обучения модели предсказания цены

# %%
Data_Purified.drop(["price"], axis= 1, inplace=True)

# %%
Clin_Data = Data_Purified

# %%
Clin_Data.to_csv("Clean_Data.csv")
